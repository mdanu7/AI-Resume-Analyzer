# %%
import pandas as pd
df = pd.read_csv("../dataset/resumes.csv")
print(df)
print("Rows and Columns:", df.shape)
print(df["job_role"].value_counts())
print(df.isnull().sum())
print(df.dtypes)
# Out:
#                                                resume          job_role
# 0    python pandas numpy sql data analysis statistics      Data Analyst
# 1   python pandas excel sql visualization data ana...      Data Analyst
# 2       python numpy pandas matplotlib sql statistics      Data Analyst
# 3                    python sql pandas power bi excel      Data Analyst
# 4             python django flask sql git api backend  Python Developer
# 5                python django flask html css sql git  Python Developer
# 6            python flask django rest api sql backend  Python Developer
# 7        python django sql github backend development  Python Developer
# 8   html css javascript react frontend web develop...     Web Developer
# 9        html css javascript bootstrap react frontend     Web Developer
# 10     html css javascript react node web development     Web Developer
# 11              javascript html css react frontend ui     Web Developer
# ...
